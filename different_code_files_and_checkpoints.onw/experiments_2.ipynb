# %%
def life_fuction(lll):
    if lll == 12:
        print("   __    \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "__|__\n")
    elif lll == 11:
        print("   ___   \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "__|__\n")
    elif lll == 10:
        print("   ____  \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "__|__\n")
    elif lll == 9:
        print("   _____ \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "  |      \n"
              "__|__\n")
    elif lll == 8:
        print("   _____  \n"
              "  |     | \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "__|__\n")
    elif lll == 7:
        print("   _____  \n"
              "  |     | \n"
              "  |     | \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "__|__\n")
    elif lll == 6:
        print("   _____  \n"
              "  |     | \n"
              "  |     | \n"
              "  |     | \n"
              "  |       \n"
              "  |       \n"
              "  |       \n"
              "__|__\n")
    elif lll == 5:
        print("   _____   \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     O  \n"
              "  |        \n"
              "  |        \n"
              "__|__\n")
    elif lll == 4:
        print("   _____   \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     O  \n"
              "  |    /   \n"
              "  |        \n"
              "__|__\n")
    elif lll == 3:
        print("   _____   \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     O  \n"
              "  |    /|  \n"
              "  |        \n"
              "__|__\n")
    elif lll == 2:
        print("   _____   \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     O  \n"
              "  |    /|\ \n"
              "  |        \n"
              "__|__\n")
    elif lll == 1:
        print("   _____   \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     |  \n"
              "  |     O  \n"
              "  |    /|\ \n"
              "  |    /   \n"
              "__|__\n")
    elif lll == 0:
        print("   _____  \n"
              "  |     | \n"
              "  |     | \n"
              "  |     | \n"
              "  |     O \n"
              "  |    /|\ \n"
              "  |    / \ \n"
              "__|__\n")
life=12     
life_fuction(life)
# Out:
#    __
#   |
#   |
#   |
#   |
#   |
#   |
# __|__
